# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0 : 3.51275
# Minibatch accuracy: 6.2%
# Validation accuracy: 12.8%
# Minibatch loss at step 50 : 1.48703
# Minibatch accuracy: 43.8%
# Validation accuracy: 50.4%
# Minibatch loss at step 100 : 1.04377
# Minibatch accuracy: 68.8%
# Validation accuracy: 67.4%
# Minibatch loss at step 150 : 0.601682
# Minibatch accuracy: 68.8%
# Validation accuracy: 73.0%
# Minibatch loss at step 200 : 0.898649
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.8%
# Minibatch loss at step 250 : 1.3637
# Minibatch accuracy: 56.2%
# Validation accuracy: 75.4%
# Minibatch loss at step 300 : 1.41968
# Minibatch accuracy: 62.5%
# Validation accuracy: 76.0%
# Minibatch loss at step 350 : 0.300648
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.2%
# Minibatch loss at step 400 : 1.32092
# Minibatch accuracy: 56.2%
# Validation accuracy: 80.4%
# Minibatch loss at step 450 : 0.556701
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.4%
# Minibatch loss at step 500 : 1.65595
# Minibatch accuracy: 43.8%
# Validation accuracy: 79.6%
# Minibatch loss at step 550 : 1.06995
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.2%
# Minibatch loss at step 600 : 0.223684
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 650 : 0.619602
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.8%
# Minibatch loss at step 700 : 0.812091
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.4%
# Minibatch loss at step 750 : 0.276302
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.3%
# Minibatch loss at step 800 : 0.450241
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.3%
# Minibatch loss at step 850 : 0.137139
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.3%
# Minibatch loss at step 900 : 0.52664
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 950 : 0.623835
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.1%
# Minibatch loss at step 1000 : 0.243114
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.9%
# Test accuracy: 90.0%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
seed=880904
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, num_channels, depth], stddev=0.1, seed=seed))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, depth, depth], stddev=0.1, seed=seed))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal([image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1, seed=seed))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal([num_hidden, num_labels], stddev=0.1, seed=seed))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    pooled = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], 'SAME')
    conv = tf.nn.conv2d(pooled, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    pooled = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], 'SAME')
    shape = pooled.get_shape().as_list()
    reshape = tf.reshape(pooled, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.197874
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.947593
# Minibatch accuracy: 25.0%
# Validation accuracy: 28.8%
# Minibatch loss at step 100: 1.307935
# Minibatch accuracy: 56.2%
# Validation accuracy: 57.2%
# Minibatch loss at step 150: 0.523721
# Minibatch accuracy: 81.2%
# Validation accuracy: 72.2%
# Minibatch loss at step 200: 0.954968
# Minibatch accuracy: 62.5%
# Validation accuracy: 76.3%
# Minibatch loss at step 250: 1.110401
# Minibatch accuracy: 68.8%
# Validation accuracy: 76.8%
# Minibatch loss at step 300: 0.444110
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.2%
# Minibatch loss at step 350: 0.464327
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.6%
# Minibatch loss at step 400: 0.357337
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.3%
# Minibatch loss at step 450: 0.742240
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.1%
# Minibatch loss at step 500: 0.651445
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.3%
# Minibatch loss at step 550: 0.727230
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.9%
# Minibatch loss at step 600: 0.285241
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.7%
# Minibatch loss at step 650: 0.894707
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.1%
# Minibatch loss at step 700: 0.884337
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.0%
# Minibatch loss at step 750: 0.126885
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.1%
# Minibatch loss at step 800: 0.555910
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.9%
# Minibatch loss at step 850: 0.932846
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.4%
# Minibatch loss at step 900: 0.590442
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.5%
# Minibatch loss at step 950: 0.555320
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.8%
# Minibatch loss at step 1000: 0.343500
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.0%
# Test accuracy: 90.6%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %% [markdown]
# ### Mimic LeNet5

# %%
seed=880904
batch_size = 256
patch_size = 5
depth_1 = 6
depth_2 = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, num_channels, depth_1], stddev=0.1, seed=seed))
  layer1_biases = tf.Variable(tf.zeros([depth_1]))
  layer2_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, depth_1, depth_2], stddev=0.1, seed=seed))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth_2]))
  layer3_weights = tf.Variable(tf.truncated_normal([image_size // 4 * image_size // 4 * depth_2, num_hidden], stddev=0.1, seed=seed))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal([num_hidden, num_labels], stddev=0.1, seed=seed))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data, do_dropout):
    weights = tf.nn.dropout(layer1_weights, 0.5) if do_dropout else layer1_weights
    conv = tf.nn.conv2d(data, weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)    
    pooled = tf.nn.avg_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], 'SAME')
    
    weights = tf.nn.dropout(layer2_weights, 0.5) if do_dropout else layer2_weights
    conv = tf.nn.conv2d(pooled, weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    pooled = tf.nn.avg_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], 'SAME')

    shape = pooled.get_shape().as_list()
    reshape = tf.reshape(pooled, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset, True)
  loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset, False))
  test_prediction = tf.nn.softmax(model(tf_test_dataset, False))

num_steps = 10001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.389081
# Minibatch accuracy: 11.3%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.308187
# Minibatch accuracy: 57.0%
# Validation accuracy: 61.2%
# Minibatch loss at step 100: 0.882227
# Minibatch accuracy: 78.1%
# Validation accuracy: 77.7%
# Minibatch loss at step 150: 0.776477
# Minibatch accuracy: 76.2%
# Validation accuracy: 79.0%
# Minibatch loss at step 200: 0.714873
# Minibatch accuracy: 77.7%
# Validation accuracy: 80.5%
# Minibatch loss at step 250: 0.647421
# Minibatch accuracy: 83.2%
# Validation accuracy: 79.9%
# Minibatch loss at step 300: 0.712544
# Minibatch accuracy: 79.3%
# Validation accuracy: 81.6%
# Minibatch loss at step 350: 0.763704
# Minibatch accuracy: 75.8%
# Validation accuracy: 82.0%
# Minibatch loss at step 400: 0.544826
# Minibatch accuracy: 82.4%
# Validation accuracy: 81.4%
# Minibatch loss at step 450: 0.701283
# Minibatch accuracy: 79.7%
# Validation accuracy: 82.4%
# Minibatch loss at step 500: 0.684637
# Minibatch accuracy: 82.0%
# Validation accuracy: 82.6%
# Minibatch loss at step 550: 0.543235
# Minibatch accuracy: 87.1%
# Validation accuracy: 83.0%
# Minibatch loss at step 600: 0.556253
# Minibatch accuracy: 85.9%
# Validation accuracy: 82.7%
# Minibatch loss at step 650: 0.605062
# Minibatch accuracy: 84.8%
# Validation accuracy: 83.5%
# Minibatch loss at step 700: 0.415449
# Minibatch accuracy: 88.3%
# Validation accuracy: 83.6%
# Minibatch loss at step 750: 0.447911
# Minibatch accuracy: 86.7%
# Validation accuracy: 83.8%
# Minibatch loss at step 800: 0.591153
# Minibatch accuracy: 79.7%
# Validation accuracy: 84.3%
# Minibatch loss at step 850: 0.478362
# Minibatch accuracy: 85.9%
# Validation accuracy: 84.3%
# Minibatch loss at step 900: 0.568020
# Minibatch accuracy: 84.8%
# Validation accuracy: 84.5%
# Minibatch loss at step 950: 0.572695
# Minibatch accuracy: 81.6%
# Validation accuracy: 84.7%
# Minibatch loss at step 1000: 0.522313
# Minibatch accuracy: 85.5%
# Validation accuracy: 84.8%
# Minibatch loss at step 1050: 0.561427
# Minibatch accuracy: 83.6%
# Validation accuracy: 84.6%
# Minibatch loss at step 1100: 0.477756
# Minibatch accuracy: 86.3%
# Validation accuracy: 84.8%
# Minibatch loss at step 1150: 0.511720
# Minibatch accuracy: 85.2%
# Validation accuracy: 84.7%
# Minibatch loss at step 1200: 0.482402
# Minibatch accuracy: 85.2%
# Validation accuracy: 85.0%
# Minibatch loss at step 1250: 0.565508
# Minibatch accuracy: 82.8%
# Validation accuracy: 84.9%
# Minibatch loss at step 1300: 0.564115
# Minibatch accuracy: 84.8%
# Validation accuracy: 85.1%
# Minibatch loss at step 1350: 0.592026
# Minibatch accuracy: 83.6%
# Validation accuracy: 85.8%
# Minibatch loss at step 1400: 0.476682
# Minibatch accuracy: 86.3%
# Validation accuracy: 85.5%
# Minibatch loss at step 1450: 0.520049
# Minibatch accuracy: 84.8%
# Validation accuracy: 85.4%
# Minibatch loss at step 1500: 0.590440
# Minibatch accuracy: 85.2%
# Validation accuracy: 85.5%
# Minibatch loss at step 1550: 0.429195
# Minibatch accuracy: 90.2%
# Validation accuracy: 85.6%
# Minibatch loss at step 1600: 0.560535
# Minibatch accuracy: 84.0%
# Validation accuracy: 85.6%
# Minibatch loss at step 1650: 0.402315
# Minibatch accuracy: 88.7%
# Validation accuracy: 85.9%
# Minibatch loss at step 1700: 0.422525
# Minibatch accuracy: 87.9%
# Validation accuracy: 86.0%
# Minibatch loss at step 1750: 0.502694
# Minibatch accuracy: 85.2%
# Validation accuracy: 86.1%
# Minibatch loss at step 1800: 0.530106
# Minibatch accuracy: 85.2%
# Validation accuracy: 85.9%
# Minibatch loss at step 1850: 0.533358
# Minibatch accuracy: 85.9%
# Validation accuracy: 85.9%
# Minibatch loss at step 1900: 0.437778
# Minibatch accuracy: 87.9%
# Validation accuracy: 86.2%
# Minibatch loss at step 1950: 0.518329
# Minibatch accuracy: 84.8%
# Validation accuracy: 86.2%
# Minibatch loss at step 2000: 0.442234
# Minibatch accuracy: 85.5%
# Validation accuracy: 86.1%
# Minibatch loss at step 2050: 0.555515
# Minibatch accuracy: 82.8%
# Validation accuracy: 86.6%
# Minibatch loss at step 2100: 0.439063
# Minibatch accuracy: 85.5%
# Validation accuracy: 86.1%
# Minibatch loss at step 2150: 0.567963
# Minibatch accuracy: 82.8%
# Validation accuracy: 86.7%
# Minibatch loss at step 2200: 0.354708
# Minibatch accuracy: 89.5%
# Validation accuracy: 86.6%
# Minibatch loss at step 2250: 0.527053
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.2%
# Minibatch loss at step 2300: 0.428192
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.5%
# Minibatch loss at step 2350: 0.379511
# Minibatch accuracy: 88.3%
# Validation accuracy: 86.5%
# Minibatch loss at step 2400: 0.457116
# Minibatch accuracy: 87.1%
# Validation accuracy: 86.7%
# Minibatch loss at step 2450: 0.450385
# Minibatch accuracy: 86.3%
# Validation accuracy: 86.5%
# Minibatch loss at step 2500: 0.585632
# Minibatch accuracy: 81.6%
# Validation accuracy: 86.6%
# Minibatch loss at step 2550: 0.352384
# Minibatch accuracy: 87.9%
# Validation accuracy: 86.6%
# Minibatch loss at step 2600: 0.582499
# Minibatch accuracy: 83.6%
# Validation accuracy: 86.7%
# Minibatch loss at step 2650: 0.516032
# Minibatch accuracy: 85.2%
# Validation accuracy: 86.8%
# Minibatch loss at step 2700: 0.420964
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# Minibatch loss at step 2750: 0.551132
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.8%
# Minibatch loss at step 2800: 0.360395
# Minibatch accuracy: 89.1%
# Validation accuracy: 86.8%
# Minibatch loss at step 2850: 0.500283
# Minibatch accuracy: 85.5%
# Validation accuracy: 86.7%
# Minibatch loss at step 2900: 0.511714
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.9%
# Minibatch loss at step 2950: 0.362885
# Minibatch accuracy: 88.3%
# Validation accuracy: 87.0%
# Minibatch loss at step 3000: 0.460992
# Minibatch accuracy: 87.9%
# Validation accuracy: 87.0%
# Minibatch loss at step 3050: 0.394919
# Minibatch accuracy: 90.2%
# Validation accuracy: 87.2%
# Minibatch loss at step 3100: 0.497880
# Minibatch accuracy: 86.7%
# Validation accuracy: 87.1%
# Minibatch loss at step 3150: 0.485464
# Minibatch accuracy: 86.3%
# Validation accuracy: 86.5%
# Minibatch loss at step 3200: 0.392811
# Minibatch accuracy: 88.3%
# Validation accuracy: 87.0%
# Minibatch loss at step 3250: 0.360470
# Minibatch accuracy: 89.5%
# Validation accuracy: 87.1%
# Minibatch loss at step 3300: 0.488820
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.2%
# Minibatch loss at step 3350: 0.463888
# Minibatch accuracy: 86.7%
# Validation accuracy: 87.3%
# Minibatch loss at step 3400: 0.376529
# Minibatch accuracy: 88.3%
# Validation accuracy: 87.2%
# Minibatch loss at step 3450: 0.526640
# Minibatch accuracy: 83.6%
# Validation accuracy: 87.1%
# Minibatch loss at step 3500: 0.426601
# Minibatch accuracy: 87.9%
# Validation accuracy: 87.3%
# Minibatch loss at step 3550: 0.361979
# Minibatch accuracy: 87.9%
# Validation accuracy: 87.1%
# Minibatch loss at step 3600: 0.422277
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.1%
# Minibatch loss at step 3650: 0.450207
# Minibatch accuracy: 87.1%
# Validation accuracy: 87.0%
# Minibatch loss at step 3700: 0.443987
# Minibatch accuracy: 88.3%
# Validation accuracy: 87.1%
# Minibatch loss at step 3750: 0.505588
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.2%
# Minibatch loss at step 3800: 0.318510
# Minibatch accuracy: 91.0%
# Validation accuracy: 87.3%
# Minibatch loss at step 3850: 0.358463
# Minibatch accuracy: 88.7%
# Validation accuracy: 87.3%
# Minibatch loss at step 3900: 0.626218
# Minibatch accuracy: 84.0%
# Validation accuracy: 87.5%
# Minibatch loss at step 3950: 0.473418
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.1%
# Minibatch loss at step 4000: 0.400750
# Minibatch accuracy: 87.9%
# Validation accuracy: 87.3%
# Minibatch loss at step 4050: 0.429221
# Minibatch accuracy: 86.3%
# Validation accuracy: 87.6%
# Minibatch loss at step 4100: 0.530304
# Minibatch accuracy: 82.4%
# Validation accuracy: 87.4%
# Minibatch loss at step 4150: 0.403108
# Minibatch accuracy: 86.7%
# Validation accuracy: 87.6%
# Minibatch loss at step 4200: 0.482852
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.5%
# Minibatch loss at step 4250: 0.371823
# Minibatch accuracy: 88.7%
# Validation accuracy: 87.2%
# Minibatch loss at step 4300: 0.467873
# Minibatch accuracy: 87.9%
# Validation accuracy: 87.5%
# Minibatch loss at step 4350: 0.458187
# Minibatch accuracy: 87.1%
# Validation accuracy: 87.3%
# Minibatch loss at step 4400: 0.401078
# Minibatch accuracy: 89.8%
# Validation accuracy: 87.6%
# Minibatch loss at step 4450: 0.378134
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.5%
# Minibatch loss at step 4500: 0.504511
# Minibatch accuracy: 83.6%
# Validation accuracy: 87.7%
# Minibatch loss at step 4550: 0.534677
# Minibatch accuracy: 83.6%
# Validation accuracy: 87.9%
# Minibatch loss at step 4600: 0.501748
# Minibatch accuracy: 85.2%
# Validation accuracy: 87.9%
# Minibatch loss at step 4650: 0.576132
# Minibatch accuracy: 85.2%
# Validation accuracy: 87.9%
# Minibatch loss at step 4700: 0.418267
# Minibatch accuracy: 87.9%
# Validation accuracy: 87.7%
# Minibatch loss at step 4750: 0.365616
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.8%
# Minibatch loss at step 4800: 0.527761
# Minibatch accuracy: 83.2%
# Validation accuracy: 87.8%
# Minibatch loss at step 4850: 0.510888
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.7%
# Minibatch loss at step 4900: 0.364081
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.7%
# Minibatch loss at step 4950: 0.462078
# Minibatch accuracy: 88.3%
# Validation accuracy: 87.8%
# Minibatch loss at step 5000: 0.429497
# Minibatch accuracy: 87.1%
# Validation accuracy: 87.7%
# Minibatch loss at step 5050: 0.513813
# Minibatch accuracy: 86.7%
# Validation accuracy: 87.8%
# Minibatch loss at step 5100: 0.365748
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.6%
# Minibatch loss at step 5150: 0.437947
# Minibatch accuracy: 88.7%
# Validation accuracy: 87.7%
# Minibatch loss at step 5200: 0.436273
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.8%
# Minibatch loss at step 5250: 0.378250
# Minibatch accuracy: 88.3%
# Validation accuracy: 88.0%
# Minibatch loss at step 5300: 0.371605
# Minibatch accuracy: 88.7%
# Validation accuracy: 88.0%
# Minibatch loss at step 5350: 0.370805
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.9%
# Minibatch loss at step 5400: 0.313854
# Minibatch accuracy: 91.0%
# Validation accuracy: 88.1%
# Minibatch loss at step 5450: 0.333719
# Minibatch accuracy: 89.8%
# Validation accuracy: 87.9%
# Minibatch loss at step 5500: 0.392974
# Minibatch accuracy: 88.7%
# Validation accuracy: 88.0%
# Minibatch loss at step 5550: 0.357248
# Minibatch accuracy: 89.8%
# Validation accuracy: 88.0%
# Minibatch loss at step 5600: 0.378655
# Minibatch accuracy: 88.7%
# Validation accuracy: 88.1%
# Minibatch loss at step 5650: 0.451385
# Minibatch accuracy: 84.8%
# Validation accuracy: 88.0%
# Minibatch loss at step 5700: 0.488485
# Minibatch accuracy: 85.5%
# Validation accuracy: 88.2%
# Minibatch loss at step 5750: 0.390156
# Minibatch accuracy: 87.1%
# Validation accuracy: 88.0%
# Minibatch loss at step 5800: 0.415580
# Minibatch accuracy: 89.5%
# Validation accuracy: 88.1%
# Minibatch loss at step 5850: 0.385539
# Minibatch accuracy: 88.3%
# Validation accuracy: 88.3%
# Minibatch loss at step 5900: 0.317521
# Minibatch accuracy: 89.5%
# Validation accuracy: 88.1%
# Minibatch loss at step 5950: 0.301627
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.3%
# Minibatch loss at step 6000: 0.354463
# Minibatch accuracy: 89.8%
# Validation accuracy: 88.3%
# Minibatch loss at step 6050: 0.355145
# Minibatch accuracy: 90.2%
# Validation accuracy: 87.9%
# Minibatch loss at step 6100: 0.288402
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.2%
# Minibatch loss at step 6150: 0.418813
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.1%
# Minibatch loss at step 6200: 0.413684
# Minibatch accuracy: 87.9%
# Validation accuracy: 88.2%
# Minibatch loss at step 6250: 0.289929
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.1%
# Minibatch loss at step 6300: 0.442485
# Minibatch accuracy: 86.7%
# Validation accuracy: 88.2%
# Minibatch loss at step 6350: 0.316157
# Minibatch accuracy: 89.8%
# Validation accuracy: 88.3%
# Minibatch loss at step 6400: 0.291664
# Minibatch accuracy: 91.0%
# Validation accuracy: 88.2%
# Minibatch loss at step 6450: 0.395195
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.2%
# Minibatch loss at step 6500: 0.439977
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.3%
# Minibatch loss at step 6550: 0.448727
# Minibatch accuracy: 84.0%
# Validation accuracy: 88.3%
# Minibatch loss at step 6600: 0.320980
# Minibatch accuracy: 91.4%
# Validation accuracy: 88.5%
# Minibatch loss at step 6650: 0.384931
# Minibatch accuracy: 88.7%
# Validation accuracy: 88.4%
# Minibatch loss at step 6700: 0.350096
# Minibatch accuracy: 88.3%
# Validation accuracy: 88.5%
# Minibatch loss at step 6750: 0.393005
# Minibatch accuracy: 88.3%
# Validation accuracy: 88.2%
# Minibatch loss at step 6800: 0.330836
# Minibatch accuracy: 91.0%
# Validation accuracy: 88.5%
# Minibatch loss at step 6850: 0.477523
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.4%
# Minibatch loss at step 6900: 0.417656
# Minibatch accuracy: 88.3%
# Validation accuracy: 88.4%
# Minibatch loss at step 6950: 0.340869
# Minibatch accuracy: 88.7%
# Validation accuracy: 88.2%
# Minibatch loss at step 7000: 0.282594
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.6%
# Minibatch loss at step 7050: 0.369989
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.4%
# Minibatch loss at step 7100: 0.382024
# Minibatch accuracy: 87.1%
# Validation accuracy: 88.5%
# Minibatch loss at step 7150: 0.437595
# Minibatch accuracy: 88.7%
# Validation accuracy: 88.5%
# Minibatch loss at step 7200: 0.315688
# Minibatch accuracy: 89.5%
# Validation accuracy: 88.5%
# Minibatch loss at step 7250: 0.455810
# Minibatch accuracy: 87.1%
# Validation accuracy: 88.6%
# Minibatch loss at step 7300: 0.303296
# Minibatch accuracy: 91.0%
# Validation accuracy: 88.4%
# Minibatch loss at step 7350: 0.355272
# Minibatch accuracy: 89.5%
# Validation accuracy: 88.5%
# Minibatch loss at step 7400: 0.498461
# Minibatch accuracy: 86.3%
# Validation accuracy: 88.7%
# Minibatch loss at step 7450: 0.365832
# Minibatch accuracy: 89.5%
# Validation accuracy: 88.7%
# Minibatch loss at step 7500: 0.308131
# Minibatch accuracy: 90.2%
# Validation accuracy: 88.6%
# Minibatch loss at step 7550: 0.287791
# Minibatch accuracy: 91.0%
# Validation accuracy: 88.5%
# Minibatch loss at step 7600: 0.311340
# Minibatch accuracy: 91.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 7650: 0.454448
# Minibatch accuracy: 87.9%
# Validation accuracy: 88.7%
# Minibatch loss at step 7700: 0.370831
# Minibatch accuracy: 89.5%
# Validation accuracy: 88.7%
# Minibatch loss at step 7750: 0.405410
# Minibatch accuracy: 90.2%
# Validation accuracy: 88.6%
# Minibatch loss at step 7800: 0.431328
# Minibatch accuracy: 86.7%
# Validation accuracy: 88.4%
# Minibatch loss at step 7850: 0.339276
# Minibatch accuracy: 91.4%
# Validation accuracy: 88.3%
# Minibatch loss at step 7900: 0.353755
# Minibatch accuracy: 89.5%
# Validation accuracy: 88.8%
# Minibatch loss at step 7950: 0.344130
# Minibatch accuracy: 89.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 8000: 0.393746
# Minibatch accuracy: 88.3%
# Validation accuracy: 88.8%
# Minibatch loss at step 8050: 0.359785
# Minibatch accuracy: 89.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 8100: 0.446528
# Minibatch accuracy: 86.7%
# Validation accuracy: 88.6%
# Minibatch loss at step 8150: 0.490010
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.4%
# Minibatch loss at step 8200: 0.297178
# Minibatch accuracy: 91.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 8250: 0.393767
# Minibatch accuracy: 85.5%
# Validation accuracy: 88.7%
# Minibatch loss at step 8300: 0.401141
# Minibatch accuracy: 89.5%
# Validation accuracy: 88.9%
# Minibatch loss at step 8350: 0.343213
# Minibatch accuracy: 92.6%
# Validation accuracy: 88.8%
# Minibatch loss at step 8400: 0.361687
# Minibatch accuracy: 90.2%
# Validation accuracy: 88.7%
# Minibatch loss at step 8450: 0.430165
# Minibatch accuracy: 88.3%
# Validation accuracy: 88.9%
# Minibatch loss at step 8500: 0.325805
# Minibatch accuracy: 89.5%
# Validation accuracy: 88.8%
# Minibatch loss at step 8550: 0.334434
# Minibatch accuracy: 90.2%
# Validation accuracy: 88.8%
# Minibatch loss at step 8600: 0.370775
# Minibatch accuracy: 87.1%
# Validation accuracy: 88.7%
# Minibatch loss at step 8650: 0.424371
# Minibatch accuracy: 87.1%
# Validation accuracy: 88.8%
# Minibatch loss at step 8700: 0.407485
# Minibatch accuracy: 87.1%
# Validation accuracy: 88.8%
# Minibatch loss at step 8750: 0.408574
# Minibatch accuracy: 87.9%
# Validation accuracy: 88.5%
# Minibatch loss at step 8800: 0.412073
# Minibatch accuracy: 87.9%
# Validation accuracy: 88.8%
# Minibatch loss at step 8850: 0.388942
# Minibatch accuracy: 87.9%
# Validation accuracy: 88.7%
# Minibatch loss at step 8900: 0.477503
# Minibatch accuracy: 85.5%
# Validation accuracy: 88.8%
# Minibatch loss at step 8950: 0.464848
# Minibatch accuracy: 85.2%
# Validation accuracy: 88.6%
# Minibatch loss at step 9000: 0.398907
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.6%
# Minibatch loss at step 9050: 0.317399
# Minibatch accuracy: 89.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 9100: 0.327544
# Minibatch accuracy: 91.4%
# Validation accuracy: 88.9%
# Minibatch loss at step 9150: 0.377294
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.9%
# Minibatch loss at step 9200: 0.374325
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.6%
# Minibatch loss at step 9250: 0.376044
# Minibatch accuracy: 89.5%
# Validation accuracy: 88.8%
# Minibatch loss at step 9300: 0.413793
# Minibatch accuracy: 88.3%
# Validation accuracy: 88.9%
# Minibatch loss at step 9350: 0.390371
# Minibatch accuracy: 86.7%
# Validation accuracy: 88.8%
# Minibatch loss at step 9400: 0.384878
# Minibatch accuracy: 88.7%
# Validation accuracy: 88.8%
# Minibatch loss at step 9450: 0.329029
# Minibatch accuracy: 89.5%
# Validation accuracy: 89.1%
# Minibatch loss at step 9500: 0.294799
# Minibatch accuracy: 91.0%
# Validation accuracy: 88.8%
# Minibatch loss at step 9550: 0.356577
# Minibatch accuracy: 88.7%
# Validation accuracy: 88.8%
# Minibatch loss at step 9600: 0.290858
# Minibatch accuracy: 91.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 9650: 0.276580
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.7%
# Minibatch loss at step 9700: 0.451231
# Minibatch accuracy: 85.2%
# Validation accuracy: 89.0%
# Minibatch loss at step 9750: 0.377059
# Minibatch accuracy: 88.3%
# Validation accuracy: 88.8%
# Minibatch loss at step 9800: 0.472759
# Minibatch accuracy: 85.5%
# Validation accuracy: 88.9%
# Minibatch loss at step 9850: 0.432641
# Minibatch accuracy: 85.2%
# Validation accuracy: 88.7%
# Minibatch loss at step 9900: 0.250423
# Minibatch accuracy: 93.0%
# Validation accuracy: 88.8%
# Minibatch loss at step 9950: 0.298327
# Minibatch accuracy: 90.2%
# Validation accuracy: 88.7%
# Minibatch loss at step 10000: 0.323213
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.0%
# Test accuracy: 95.0%
